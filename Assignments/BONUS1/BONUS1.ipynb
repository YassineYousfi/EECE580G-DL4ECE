# %% [markdown]
# # EECE 580G Bonus problem 1 -  MLE of a Gamma random variable

# %% [markdown]
# Let $X \sim \text{Gamma}(\alpha)$ a random variable following the Gamma distribution, the pdf of the Gamma distribution is given by:
#
# $$f(x;\alpha) = \frac{1}{\Gamma(\alpha)}e^{-x}x^{\alpha-1} \quad \text{ for } x > 0 \quad \alpha > 0 $$
# Where $\Gamma(z)=\int_0^\infty x^{z-1} e^{-x}\,dx$ is the gamma function.
#
# 1. Show that the MLE estimate of $\alpha$ denoted $\hat{\alpha}$ verifies:
# $$ \frac{\Gamma'(\hat{\alpha})}{\Gamma(\hat{\alpha})} = \frac{1}{n}\sum_{i=1}^{n}\log(x_i)$$
# Where $\Gamma'$ is the first derivative of the Gamma function, note that $\Gamma'/\Gamma$ is also called the digamma function (the logarithmic derivative of the gamma function).
# 2. Can you solve the equation analytically?
# 3. Write a script using `scipy.optimize.fmin` to solve the MLE problem numerically.
# 3. Write a new script using `scipy.optimize.fsolve` and `scipy.special.digamma` to solve the MLE problem numerically using the property you proved in (1). Compare both approaches for different values of $\alpha$.

# %%
from scipy.optimize import fmin
import numpy as np
from scipy.stats import gamma
from scipy.special import gamma as gammafunc

x = gamma.rvs(a=200,size=10000)

def total_neglog_likelihood(alpha, x):
  # YOUR CODE HERE
  return 0

# YOUR CODE HERE
# Use fmin

from scipy.optimize import fsolve
from scipy.special import digamma 

x = gamma.rvs(a=200,size=10000)

def grad_total_log_likelihood(alpha, x):
  # YOUR CODE HERE
  return 0 

# YOUR CODE HERE
# Use fsolve
